# %%
import seaborn as sns
import pandas as pd
from scipy.stats import f_oneway

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = df[['age','pclass']].dropna()

# %%
df['pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
class_1 = df[df['pclass']==1]['age']
class_2 = df[df['pclass']==2]['age']
class_3 = df[df['pclass']==3]['age']

# %%
print(class_1)
print(class_2)
print(class_3)
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 11     58.0
# 23     28.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: age, Length: 186, dtype: float64
# 9      14.0
# 15     55.0
# 20     35.0
# 21     34.0
# 33     66.0
#        ...
# 866    27.0
# 874    28.0
# 880    25.0
# 883    28.0
# 886    27.0
# Name: age, Length: 173, dtype: float64
# 0      22.0
# 2      26.0
# 4      35.0
# 7       2.0
# 8      27.0
#        ...
# 881    33.0
# 882    22.0
# 884    25.0
# 885    39.0
# 890    32.0
# Name: age, Length: 355, dtype: float64

# %%
f_ststs,p_value=f_oneway(class_1,class_2,class_3)

# %%
print(f_ststs)
print(p_value)
# Out:
# 57.44348434067624
# 7.487984171957403e-24

# %%
alpha = 0.05
if p_value < alpha:
    print("we reject the null hypothesis and there is a significant relationship between in atleast one passenger class")
else:
    print("there is no significant difference ")
# Out:
# we reject the null hypothesis and there is a significant relationship between in atleast one passenger class
